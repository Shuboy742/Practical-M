# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Conv2D, Conv2DTranspose
from tensorflow.keras.layers import BatchNormalization, LeakyReLU
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import numpy as np
import matplotlib.pyplot as plt

# %%
# Load MNIST data
(train_images, _), (_, _) = tf.keras.datasets.mnist.load_data()

# Normalize pixel values to [-1, 1]
train_images = (train_images.astype(np.float32) - 127.5) / 127.5

# Add channel dimension for grayscale images
train_images = np.expand_dims(train_images, axis=-1)

# %%
def build_generator():
    noise_shape = (100,)
    
    model = tf.keras.Sequential([
        Dense(7*7*256, input_shape=noise_shape),
        Reshape((7, 7, 256)),
        BatchNormalization(),
        Conv2DTranspose(128, kernel_size=5, strides=1, padding='same', activation='relu'),
        BatchNormalization(),
        Conv2DTranspose(64, kernel_size=5, strides=2, padding='same', activation='relu'),
        BatchNormalization(),
        Conv2DTranspose(1, kernel_size=5, strides=2, padding='same', activation='tanh')
    ])
    
    return model

def build_discriminator():
    model = tf.keras.Sequential([
        Conv2D(64, kernel_size=5, strides=2, padding='same', input_shape=(28, 28, 1)),
        LeakyReLU(alpha=0.2),
        Conv2D(128, kernel_size=5, strides=2, padding='same'),
        LeakyReLU(alpha=0.2),
        Flatten(),
        Dense(1, activation='sigmoid')
    ])
    
    return model

# Instantiate generator and discriminator
generator = build_generator()
discriminator = build_discriminator()

# %%
discriminator.compile(optimizer=Adam(lr=0.0002, beta_1=0.5), loss='binary_crossentropy')
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
def build_gan(generator, discriminator):
    discriminator.trainable = False
    
    gan_input = Input(shape=(100,))
    generated_image = generator(gan_input)
    gan_output = discriminator(generated_image)
    
    gan = Model(gan_input, gan_output)
    gan.compile(loss='binary_crossentropy', optimizer=Adam(lr=0.0002, beta_1=0.5))
    
    return gan

# Instantiate GAN
gan = build_gan(generator, discriminator)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %%
def train_gan(generator, discriminator, gan, images, epochs=100, batch_size=128, sample_interval=10):
    real_labels = np.ones((batch_size, 1))
    fake_labels = np.zeros((batch_size, 1))
    
    for epoch in range(epochs):
        # Select a random batch of real images
        idx = np.random.randint(0, images.shape[0], batch_size)
        real_images = images[idx]
        
        # Generate random noise as input to the generator
        noise = np.random.normal(0, 1, (batch_size, 100))
        
        # Generate fake images using the generator
        generated_images = generator.predict(noise)
        
        # Train the discriminator
        d_loss_real = discriminator.train_on_batch(real_images, real_labels)
        d_loss_fake = discriminator.train_on_batch(generated_images, fake_labels)
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
        
        # Train the generator (via the GAN model)
        g_loss = gan.train_on_batch(noise, real_labels)
        
        # Print training progress
        if epoch % sample_interval == 0:
            print(f"Epoch {epoch}: D loss = {d_loss}, G loss = {g_loss}")
            save_generated_images(epoch, generator)

def save_generated_images(epoch, generator, examples=10, dim=(1, 10), figsize=(10, 1)):
    noise = np.random.normal(0, 1, (examples, 100))
    generated_images = generator.predict(noise)
    generated_images = 0.5 * generated_images + 0.5
    
    plt.figure(figsize=figsize)
    for i in range(examples):
        plt.subplot(dim[0], dim[1], i+1)
        plt.imshow(generated_images[i, :, :, 0], cmap='gray')
        plt.axis('off')
    plt.tight_layout()
    plt.savefig(f"gan_generated_image_epoch_{epoch}.png")
    plt.close()

# Train the GAN
train_gan(generator, discriminator, gan, train_images, epochs=200, batch_size=128, sample_interval=20)
# Out:
# 4/4 [==============================] - 0s 46ms/step
# Epoch 0: D loss = 0.7088288366794586, G loss = 0.589092493057251
# 1/1 [==============================] - 0s 142ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 44ms/step
# Epoch 20: D loss = 0.0054026765283197165, G loss = 0.03800511360168457
# 1/1 [==============================] - 0s 34ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 49ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 52ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# Epoch 40: D loss = 0.04575672559440136, G loss = 0.38774552941322327
# 1/1 [==============================] - 0s 38ms/step
# 4/4 [==============================] - 0s 49ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 54ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 51ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 44ms/step
# Epoch 60: D loss = 0.02050201315432787, G loss = 0.03230335935950279
# 1/1 [==============================] - 0s 37ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 52ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# Epoch 80: D loss = 0.007450838340446353, G loss = 0.006724666338413954
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 49ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# Epoch 100: D loss = 0.003333802567794919, G loss = 0.003188262227922678
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 99ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# Epoch 120: D loss = 0.00484914577100426, G loss = 0.006017907988280058
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step
# Epoch 140: D loss = 0.002331240277271718, G loss = 0.0014574737288057804
# 1/1 [==============================] - 0s 35ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 50ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 48ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 44ms/step
# Epoch 160: D loss = 0.6666840314865112, G loss = 0.5875875353813171
# 1/1 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 49ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 39ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 40ms/step
# Epoch 180: D loss = 0.45236586034297943, G loss = 1.1464636325836182
# 1/1 [==============================] - 0s 40ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 42ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 41ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 44ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 51ms/step
# 4/4 [==============================] - 0s 51ms/step
# 4/4 [==============================] - 0s 45ms/step
# 4/4 [==============================] - 0s 51ms/step
# 4/4 [==============================] - 0s 47ms/step
# 4/4 [==============================] - 0s 46ms/step
# 4/4 [==============================] - 0s 43ms/step
# 4/4 [==============================] - 0s 54ms/step
# 4/4 [==============================] - 0s 52ms/step
# 4/4 [==============================] - 0s 52ms/step
# 4/4 [==============================] - 0s 47ms/step
